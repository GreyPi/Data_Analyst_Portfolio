# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots created

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('movies.csv', encoding='latin-1')

# %%
# Checking out the Data

df.head()
# Out:
#      budget                                 company  ...  year yearcorrect
# 0   8000000           Columbia Pictures Corporation  ...  1986        1986
# 1   6000000                      Paramount Pictures  ...  1986        1986
# 2  15000000                      Paramount Pictures  ...  1986        1986
# 3  18500000  Twentieth Century Fox Film Corporation  ...  1986        1986
# 4   9000000                    Walt Disney Pictures  ...  1986        1986
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Taking care of missing data

# %%
for col in df.columns:
  pct_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col, pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
# If there was missing Data a possible solution
# could be replacing NA values with the mean of all values

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(df[:, :])
df[:, :] = imputer.transform(df[:, :])

# %%
# Data types for Coulmns

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
# Helping with the view for the columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# Fixing the year column

df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
# Checking out the Highest and Lowest Grossing Films

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#          budget                                 company  ...  year yearcorrect
# 6380  245000000                               Lucasfilm  ...  2015        2015
# 5061  237000000  Twentieth Century Fox Film Corporation  ...  2009        2009
# 2420  200000000  Twentieth Century Fox Film Corporation  ...  1997        1997
# 6391  150000000                      Universal Pictures  ...  2015        2015
# 5723  220000000                          Marvel Studios  ...  2012        2012
# ...         ...                                     ...  ...   ...         ...
# 5917          0           Zentropa International Norway  ...  2012        2013
# 5699          0                        Isle of Man Film  ...  2011        2012
# 6066          0                           Cinetel Films  ...  2013        2014
# 2594   15000000                                Daybreak  ...  1997        1997
# 6784          0                           Magic Lantern  ...  2016        2016
#
# ...

# %%
# Option to check out all the data in IDE

pd.set_option('display.max_rows', None)

# %%
# Check for duplicate data and drop if there are
# Double checking data before deletion is always good

# How to check one attribute at a time
df['company'].drop_duplicates().sort_values(ascending=False)

# Check and drop all data
df.drop_duplicates()
# Out:
# 5288                        micro_scope
# 3486                           i5 Films
# 6084                               erbp
# 3225                     double A Films
# 2707        Zucker Brothers Productions
#                      ...
# 3527                          120 Films
# 5466              10th Hole Productions
# 2815                 101st Street Films
# 3208                 1+2 Seisaku Iinkai
# 3832    "DIA" Productions GmbH & Co. KG
# Name: company, Length: 2179, dtype: object

# %% [markdown]
# ## Scatter Plot Budget v Gross

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget v Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# %% [markdown]
# ## Plot using Seaborn!

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'gray'}, line_kws={'color': 'blue'})

# %% [markdown]
# ## Looking at the Correlation in the Data

# %%
df.corr(method='pearson') # Options: pearson, kendall, spearman
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.698639  0.231672 -0.027868  0.616419  0.300553
# gross    0.698639  1.000000  0.202905  0.045582  0.667869  0.139467
# runtime  0.231672  0.202905  1.000000  0.398840  0.287150  0.107902
# score   -0.027868  0.045582  0.398840  1.000000  0.392199  0.103598
# votes    0.616419  0.667869  0.287150  0.392199  1.000000  0.485588
# year     0.300553  0.139467  0.107902  0.103598  0.485588  1.000000

# %% [markdown]
# There appears to be a high correlation between the budget and gross attributes

# %% [markdown]
# ## Heat Map Correlation Matrix

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %% [markdown]
# ## Encoding or Numerazing the object data types in the data

# %%
df_numerized = df

for col_name in df_numerized.columns:
  if(df_numerized[col_name].dtype == 'object'):
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#         budget  company  country  director  ...   votes  writer  year  yearcorrect
# 0      8000000      665       54      2192  ...  299174    3716  1986            0
# 1      6000000     1680       54      1296  ...  264740    1970  1986            0
# 2     15000000     1680       54      2645  ...  236909    1852  1986            0
# 3     18500000     2062       54      1066  ...  540152    1629  1986            0
# 4      9000000     2122       54      2123  ...   36636    2549  1986            0
# ...        ...      ...      ...       ...  ...     ...     ...   ...          ...
# 6815         0     1013       53      1623  ...    9161    1800  2016           30
# 6816         0     1914       54      1989  ...    1959    3008  2016           30
# 6817   3500000     2124       54      2313  ...   36333     450  2016           30
# 6818         0      415       54      1914  ...    6947    2946  2016           30
# ...

# %%
# Correlation Matrix with the numerized data

correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Compares the correlation between attributes for every attribute

correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.187205
#              country        0.137635
#              director       0.011602
#              genre         -0.346794
#                               ...
# yearcorrect  star          -0.026050
#              votes          0.220797
#              writer        -0.004546
#              year           0.996229
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
# Sorting the values of the pairs

sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.346794
# budget       genre         -0.346794
# gross        genre         -0.242676
# genre        gross         -0.242676
# score        country       -0.174414
#                               ...
# director     director       1.000000
# country      country        1.000000
# company      company        1.000000
# year         year           1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
# Correlations that are above 50%

high_corr = sorted_pairs[(sorted_pairs > 0.5)]

high_corr
# Out:
# votes        budget         0.503924
# budget       votes          0.503924
# votes        gross          0.662457
# gross        votes          0.662457
#              budget         0.712196
# budget       gross          0.712196
# released     year           0.996187
# year         released       0.996187
# yearcorrect  year           0.996229
# year         yearcorrect    0.996229
# yearcorrect  released       0.999389
# released     yearcorrect    0.999389
# budget       budget         1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# ...

# %% [markdown]
# It appears the Vote and Budget attribute have the highest correlation with Gross earnings
